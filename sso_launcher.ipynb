# %% [markdown]
# <a href="https://colab.research.google.com/github/ja7jnv/Astronomy/blob/main/sso_launcher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ja7jnv/Astronomy
# %cd Astronomy/sso
# !python sso.py
# Out:
# Cloning into 'Astronomy'...
# remote: Enumerating objects: 480, done.
# remote: Counting objects: 100% (161/161), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 480 (delta 117), reused 89 (delta 50), pack-reused 319 (from 1)
# Receiving objects: 100% (480/480), 621.34 KiB | 4.31 MiB/s, done.
# Resolving deltas: 100% (321/321), done.
# /content/Astronomy/sso
# Traceback (most recent call last):
#   File "/content/Astronomy/sso/sso.py", line 5, in <module>
#     from interpreter import SSOInterpreter
#   File "/content/Astronomy/sso/interpreter.py", line 3, in <module>
#     from classes import SSOObserver, SSOCalculator, SSOSystemConfig
#   File "/content/Astronomy/sso/classes.py", line 5, in <module>
#     import ephem
# ModuleNotFoundError: No module named 'ephem'
