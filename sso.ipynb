# %% [markdown]
# <a href="https://colab.research.google.com/github/ja7jnv/Astronomy/blob/develop/sso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ja7jnv/Astronomy
# %cd Astronomy/sso
# !pip install ephem
# !python sso.py
# Out:
# Cloning into 'Astronomy'...
# remote: Enumerating objects: 483, done.
# remote: Counting objects: 100% (164/164), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 483 (delta 119), reused 89 (delta 50), pack-reused 319 (from 1)
# Receiving objects: 100% (483/483), 622.11 KiB | 4.20 MiB/s, done.
# Resolving deltas: 100% (323/323), done.
# /content/Astronomy/sso/Astronomy/sso
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 20.6 MB/s eta 0:00:00
# ...
# Solar System Observer (SSO) DSL - Interpreter Mode
# (Type 'exit' to quit)
# sso> here
# 0.0
# sso> Here=Moon
# Default ovserver: <ephem.Moon "Moon" at 0x7db1c4fdbd20>
# sso> Here->Moon
# Error: Invalid arrow operation <ephem.Moon "Moon" at 0x7db1c4fdbd20> -> <ephem.Moon "Moon" at 0x7db1c4fdbd20>
# sso> Time
# UTC+Tz: 2026/02/24 11:50:42 [+9.0]
# 2026/2/24 02:50:42
# sso>
