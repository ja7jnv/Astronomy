# %% [markdown]
# <a href="https://colab.research.google.com/github/ja7jnv/Astronomy/blob/main/sso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ja7jnv/Astronomy
# %cd Astronomy/sso
# !pip install ephem
# !python sso.py
# Out:
# Cloning into 'Astronomy'...
# remote: Enumerating objects: 486, done.
# remote: Counting objects: 100% (167/167), done.
# remote: Compressing objects: 100% (114/114), done.
# remote: Total 486 (delta 122), reused 89 (delta 50), pack-reused 319 (from 1)
# Receiving objects: 100% (486/486), 622.97 KiB | 9.16 MiB/s, done.
# Resolving deltas: 100% (326/326), done.
# /content/Astronomy/sso
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 18.2 MB/s eta 0:00:00
# ...
# Solar System Observer (SSO) DSL - Interpreter Mode
# (Type 'exit' to quit)
# sso>
